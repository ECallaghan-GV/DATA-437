# %% [markdown]
# # Variable Engineering

# %%
## Reading the csv file

import pandas as pd
import numpy as np

pd.set_option('display.max_rows', None, 'display.max_columns', None)

nfl = pd.read_csv('aggregated_cleaned_spreadspoke_scores.csv')

nfl.head()
# Out:
#            team_home team_home_name team_home_id           team_away  \
# 0  Arizona Cardinals        Arizona          ARI      Dallas Cowboys
# 1  Arizona Cardinals        Arizona          ARI      Denver Broncos
# 2  Arizona Cardinals        Arizona          ARI   Las Vegas Raiders
# 3  Arizona Cardinals        Arizona          ARI    Los Angeles Rams
# 4  Arizona Cardinals        Arizona          ARI  New Orleans Saints
#
#   team_away_name team_away_id schedule_date  schedule_season schedule_week  \
# 0         Dallas          DAL    12/25/2010             2010            16
# 1         Denver          DEN    12/12/2010             2010            14
# 2      Las Vegas          LVR     9/26/2010             2010             3
# 3        LA Rams          LAR     12/5/2010             2010            13
# 4    New Orleans           NO    10/10/2010             2010             5
#
#    schedule_playoff  score_home  score_away team_favorite_id  spread_favorite  \
# 0                 0          27          26              DAL             -7.5
# 1                 0          43          13              DEN             -4.0
# 2                 0          24          23              ARI             -5.5
# 3                 0           6          19              LAR             -3.5
# 4                 0          30          20               NO             -7.0
#
#    over_under_line                        stadium  stadium_neutral  \
# 0             45.0  University of Phoenix Stadium                0
# 1             44.0  University of Phoenix Stadium                0
# 2             39.0  University of Phoenix Stadium                0
# 3             44.0  University of Phoenix Stadium                0
# 4             45.5  University of Phoenix Stadium                0
#
#    team_home_ppg  team_home_oppg  team_home_ypg  team_home_oypg  \
# 0           18.1            27.1          269.3           373.6
# 1           18.1            27.1          269.3           373.6
# 2           18.1            27.1          269.3           373.6
# 3           18.1            27.1          269.3           373.6
# 4           18.1            27.1          269.3           373.6
#
#    team_home_fdpg  team_home_ofdpg  team_home_tapg  team_home_tpg  \
# 0            15.4             21.7             1.9            2.2
# 1            15.4             21.7             1.9            2.2
# 2            15.4             21.7             1.9            2.2
# 3            15.4             21.7             1.9            2.2
# 4            15.4             21.7             1.9            2.2
#
#    team_home_pypg  team_home_opypg  team_home_asm  team_away_ppg  \
# 0            54.4             55.9           -9.1           24.6
# 1            54.4             55.9           -9.1           21.5
# 2            54.4             55.9           -9.1           25.6
# 3            54.4             55.9           -9.1           18.1
# 4            54.4             55.9           -9.1           24.7
#
#    team_away_oppg  team_away_ypg  team_away_oypg  team_away_fdpg  \
# 0            27.2          364.1           351.8            20.2
# 1            29.4          348.9           390.8            19.2
# 2            23.2          354.6           322.9            19.0
# 3            20.5          302.9           336.8            18.0
# 4            20.5          378.5           312.6            22.5
#
#    team_away_ofdpg  team_away_tapg  team_away_tpg  team_away_pypg  \
# 0             19.2             1.9            1.9            53.9
# 1             20.7             1.1            1.7            59.0
# 2             18.1             1.5            1.6            79.8
# 3             18.8             1.6            1.3            54.8
# 4             17.2             1.5            1.9            54.3
#
#    team_away_opypg  team_away_asm
# 0             40.1           -2.6
# 1             57.6           -7.9
# 2             72.6            2.4
# 3             63.0           -2.4
# 4             43.5            4.2

# %%
## Subsetting the data to remove all observations without a favored team

nfl = nfl[nfl['team_favorite_id'] != 'PICK']

# %% [markdown]
# ### Real Over/Under Line

# %%
## Real Over Under Line is the sum of points from both teams

## Changing over_under_line to numeric
nfl['over_under_line'] = pd.to_numeric(nfl['over_under_line'])

nfl['real_over_under_line'] = nfl['score_home'] + nfl['score_away']

# %%
## over_under is a categorical variable (0 for under and 1 for over the projected score)
## Over Under Push when real points = estimated points

nfl['over_under'] = np.where(nfl['over_under_line'] < nfl['real_over_under_line'], 1, 0)
nfl['over_under_push'] = np.where(nfl['over_under_line'] == nfl['real_over_under_line'], 1, 0)

# %% [markdown]
# ### Money Line

# %%
nfl['favorite_team'] = np.where(nfl['team_favorite_id'] == nfl['team_home_id'], nfl['team_home'], nfl['team_away'])

nfl['favorite_team_score'] = np.where(nfl['favorite_team'] == nfl['team_home'], nfl['score_home'], nfl['score_away'])

nfl['underdog_team'] = np.where(nfl['team_favorite_id'] == nfl['team_home_id'], nfl['team_away'], nfl['team_home'])

nfl['underdog_team_score'] = np.where(nfl['favorite_team'] == nfl['team_home'], nfl['score_away'], nfl['score_home'])

nfl['favorite_team_win'] = np.where(nfl['favorite_team_score'] > nfl['underdog_team_score'], 1, 0)

# %% [markdown]
# ### Favorite Spread

# %%
nfl['favorite_team_cover'] = np.where((nfl['favorite_team_score'] + nfl['spread_favorite']) > nfl['underdog_team_score'], 1, 0)

# %% [markdown]
# ### Dropping unnecessary columns following variable engineering

# %%
nfl = nfl.drop(columns = ['team_favorite_id', 'team_home_name', 'team_home_id', 'team_away_name', 'team_away_id'])

# %%
nfl = nfl[['schedule_date', 'schedule_season', 'schedule_week', 'schedule_playoff', 'team_home', 'team_away', 'score_home', 'score_away',
          'stadium', 'stadium_neutral', 'team_home_ppg', 'team_home_oppg', 'team_home_ypg', 'team_home_oypg', 'team_home_fdpg',
          'team_home_ofdpg', 'team_home_tapg', 'team_home_tpg', 'team_home_pypg', 'team_home_opypg', 'team_home_asm', 'team_away_ppg', 
           'team_away_oppg', 'team_away_ypg', 'team_away_oypg', 'team_away_fdpg', 'team_away_ofdpg', 'team_away_tapg', 'team_away_tpg', 
           'team_away_pypg', 'team_away_opypg', 'team_away_asm', 'over_under_line', 'real_over_under_line', 'over_under', 'over_under_push',
          'favorite_team', 'favorite_team_score', 'underdog_team', 'underdog_team_score', 'spread_favorite', 'favorite_team_win',
          'favorite_team_cover']]

# %%
nfl.head()
# Out:
#   schedule_date  schedule_season schedule_week  schedule_playoff  \
# 0    12/25/2010             2010            16                 0
# 1    12/12/2010             2010            14                 0
# 2     9/26/2010             2010             3                 0
# 3     12/5/2010             2010            13                 0
# 4    10/10/2010             2010             5                 0
#
#            team_home           team_away  score_home  score_away  \
# 0  Arizona Cardinals      Dallas Cowboys          27          26
# 1  Arizona Cardinals      Denver Broncos          43          13
# 2  Arizona Cardinals   Las Vegas Raiders          24          23
# 3  Arizona Cardinals    Los Angeles Rams           6          19
# 4  Arizona Cardinals  New Orleans Saints          30          20
#
#                          stadium  stadium_neutral  team_home_ppg  \
# 0  University of Phoenix Stadium                0           18.1
# 1  University of Phoenix Stadium                0           18.1
# 2  University of Phoenix Stadium                0           18.1
# 3  University of Phoenix Stadium                0           18.1
# 4  University of Phoenix Stadium                0           18.1
#
#    team_home_oppg  team_home_ypg  team_home_oypg  team_home_fdpg  \
# 0            27.1          269.3           373.6            15.4
# 1            27.1          269.3           373.6            15.4
# 2            27.1          269.3           373.6            15.4
# 3            27.1          269.3           373.6            15.4
# 4            27.1          269.3           373.6            15.4
#
#    team_home_ofdpg  team_home_tapg  team_home_tpg  team_home_pypg  \
# 0             21.7             1.9            2.2            54.4
# 1             21.7             1.9            2.2            54.4
# 2             21.7             1.9            2.2            54.4
# 3             21.7             1.9            2.2            54.4
# 4             21.7             1.9            2.2            54.4
#
#    team_home_opypg  team_home_asm  team_away_ppg  team_away_oppg  \
# 0             55.9           -9.1           24.6            27.2
# 1             55.9           -9.1           21.5            29.4
# 2             55.9           -9.1           25.6            23.2
# 3             55.9           -9.1           18.1            20.5
# 4             55.9           -9.1           24.7            20.5
#
#    team_away_ypg  team_away_oypg  team_away_fdpg  team_away_ofdpg  \
# 0          364.1           351.8            20.2             19.2
# 1          348.9           390.8            19.2             20.7
# 2          354.6           322.9            19.0             18.1
# 3          302.9           336.8            18.0             18.8
# 4          378.5           312.6            22.5             17.2
#
#    team_away_tapg  team_away_tpg  team_away_pypg  team_away_opypg  \
# 0             1.9            1.9            53.9             40.1
# 1             1.1            1.7            59.0             57.6
# 2             1.5            1.6            79.8             72.6
# 3             1.6            1.3            54.8             63.0
# 4             1.5            1.9            54.3             43.5
#
#    team_away_asm  over_under_line  real_over_under_line  over_under  \
# 0           -2.6             45.0                    53           1
# 1           -7.9             44.0                    56           1
# 2            2.4             39.0                    47           1
# 3           -2.4             44.0                    25           0
# 4            4.2             45.5                    50           1
#
#    over_under_push       favorite_team  favorite_team_score  \
# 0                0      Dallas Cowboys                   26
# 1                0      Denver Broncos                   13
# 2                0   Arizona Cardinals                   24
# 3                0    Los Angeles Rams                   19
# 4                0  New Orleans Saints                   20
#
#        underdog_team  underdog_team_score  spread_favorite  favorite_team_win  \
# 0  Arizona Cardinals                   27             -7.5                  0
# 1  Arizona Cardinals                   43             -4.0                  0
# 2  Las Vegas Raiders                   23             -5.5                  1
# 3  Arizona Cardinals                    6             -3.5                  1
# 4  Arizona Cardinals                   30             -7.0                  0
#
#    favorite_team_cover
# 0                    0
# 1                    0
# 2                    0
# 3                    1
# 4                    0

# %% [markdown]
# ### Exporting NFL as final data set for analysis

# %%
nfl.to_csv('final_spreadspoke_scores.csv', index = False, header = True)
